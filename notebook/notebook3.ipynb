# %% [markdown]
# ### Lien Utile :
#
# - [OCR CAPTCHA KERAS DOC](https://keras.io/examples/vision/captcha_ocr/)
# - [Explanation Model](https://harald-scheidl.medium.com/intuitively-understanding-connectionist-temporal-classification-3797e43a86c)

# %% [markdown]
# CAPTCHA -> CNN -> RNN -> CTC -> Pred

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import tensorflow as tf
import keras
from keras import ops, layers

print(tf.__version__)
print(keras.__version__)
print(ops.ones((2, 3)))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 6
#       4 import tensorflow as tf
#       5 import keras
# ----> 6 from keras import ops, layers
#       8 print(tf.__version__)
#       9 print(keras.__version__)
#
# File c:\Mosef\webscrapping\projet\Captchas-Automatic-Resolution\.venv\lib\site-packages\keras\ops\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.ops import image as image
#       8 from keras.ops import linalg as linalg
#       9 from keras.ops import nn as nn
#
# File c:\Mosef\webscrapping\projet\Captchas-Automatic-Resolution\.venv\lib\site-packages\keras\ops\image\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.ops.image import affine_transform as affine_transform
#       8 from keras.src.ops.image import crop_images as crop_images
#       9 from keras.src.ops.image import elastic_transform as elastic_transform
#
# File c:\Mosef\webscrapping\projet\Captchas-Automatic-Resolution\.venv\lib\site-packages\keras\src\ops\__init__.py:6
#       1 # from keras.src.ops.numpy import Matmul, matmul
#       2 # from keras.src.ops.numpy import Add, add
#       3 # from keras.src.ops.numpy import Multiply, multiply
#       5 from keras.src.backend import cast
# ----> 6 from keras.src.backend import cond
#       7 from keras.src.backend import is_tensor
#       8 from keras.src.backend import name_scope
#
# ImportError: cannot import name 'cond' from 'keras.src.backend' (c:\Mosef\webscrapping\projet\Captchas-Automatic-Resolution\.venv\lib\site-packages\keras\src\backend.py)

# %%
import keras
print(keras.__version__)
# Out:
# 2.15.0
